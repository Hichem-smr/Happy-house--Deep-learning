# %% [markdown]
# # If you happy and I know it you can enter my House
#
# You'll see how you can in a couple of hours build a deep learning algorithm.

# %%
import numpy as np
import tensorflow as tf
from sklearn.metrics import confusion_matrix
import seaborn as sns
import h5py
from keras import layers
from keras.layers import Input, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling2D, MaxPooling2D, Dropout, GlobalMaxPooling2D, GlobalAveragePooling2D
from keras.models import Model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
from keras.models import Sequential
from tensorflow.keras.optimizers import RMSprop

import pydot
from IPython.display import SVG


import keras.backend as K
K.set_image_data_format('channels_last')
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

# %%
def load_dataset(path_to_train, path_to_test):
    train_dataset = h5py.File(path_to_train)
    train_x = np.array(train_dataset['train_set_x'][:])
    train_y = np.array(train_dataset['train_set_y'][:])

    test_dataset = h5py.File(path_to_test)
    test_x = np.array(test_dataset['test_set_x'][:])
    test_y = np.array(test_dataset['test_set_y'][:])

    # y reshaped
    train_y = train_y.reshape((1, train_x.shape[0]))
    test_y = test_y.reshape((1, test_y.shape[0]))

    return train_x, train_y, test_x, test_y

# %% [markdown]
# This dataset can be used to solve the Happy House problem.
# Where, we allow a person to enter the house only if he/she is smiling!
# So, a smile detector!

# %% [markdown]
# ![Texte alternatif…](https://raw.githubusercontent.com/Kulbear/deep-learning-coursera/master/Convolutional%20Neural%20Networks/images/house-members.png)

# %% [markdown]
# Details of the "Happy" dataset:
#
# * Images are of shape (64,64,3)
# * Training: 600 pictures
# * Test: 150 pictures

# %% [markdown]
# # Load Dataset

# %%
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig = load_dataset("train_happy.h5","test_happy.h5")

# Normalize image vectors
X_train = X_train_orig/255.
X_test = X_test_orig/255

# Reshape
Y_train = Y_train_orig.T
Y_test = Y_test_orig.T

print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 600
# number of test examples = 150
# X_train shape: (600, 64, 64, 3)
# Y_train shape: (600, 1)
# X_test shape: (150, 64, 64, 3)
# Y_test shape: (150, 1)

# %%
# Sample image from dataset
print("Image shape :",X_train_orig[10].shape)
imshow(X_train_orig[14])
print(Y_test[14])
# Out:
# Image shape : (64, 64, 3)
# [0]

# %% [markdown]
# # Building Model

# %% [markdown]
# _________________________________________________________________
#
# conv2d_3 (Conv2D)            (None, 64, 64, 32)        4736
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64, 64, 32)        128
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 32769
# _________________________________________________________________

# %%
from keras.layers import Conv2D, Dense, MaxPool2D, Flatten, Dropout, Activation

model = Sequential()
#Conv layer 1
model.add(Conv2D(filters=20, kernel_size = (3, 3), padding = "same", strides=(1,2), input_shape=(64, 64, 3),activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

#Conv layer 2
model.add(Conv2D(filters=20, kernel_size = (3, 3), padding = "same", strides=(1,2),activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

#Flatten layer
model.add(Flatten())

#Fully connected layers
model.add(Dense(units = 64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units = 64, activation='relu'))
model.add(Dropout(0.2))

#output layer
model.add(Dense(units = 1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_77"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_98 (Conv2D)          (None, 64, 32, 20)        560
#
#  max_pooling2d_96 (MaxPoolin  (None, 32, 16, 20)       0
#  g2D)
#
#  conv2d_99 (Conv2D)          (None, 32, 8, 20)         3620
#
#  max_pooling2d_97 (MaxPoolin  (None, 16, 4, 20)        0
#  g2D)
#
#  flatten_76 (Flatten)        (None, 1280)              0
#
#  dense_96 (Dense)            (None, 64)                81984
#
#  dropout_12 (Dropout)        (None, 64)                0
#
#  dense_97 (Dense)            (None, 64)                4160
#
#  dropout_13 (Dropout)        (None, 64)                0
#
#  dense_98 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 90,389
# Trainable params: 90,389
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=RMSprop(), loss='binary_crossentropy', metrics=["accuracy"])

# %%
history = model.fit(X_train,
                    Y_train,
                    batch_size=10,
                    epochs=50,
                    verbose=1,
                    validation_split=0.2)
# Out:
# Epoch 1/50
# 48/48 [==============================] - 1s 13ms/step - loss: 0.6941 - accuracy: 0.4896 - val_loss: 0.6746 - val_accuracy: 0.6833
# Epoch 2/50
# 48/48 [==============================] - 1s 10ms/step - loss: 0.6398 - accuracy: 0.6458 - val_loss: 0.7664 - val_accuracy: 0.4500
# Epoch 3/50
# 48/48 [==============================] - 1s 11ms/step - loss: 0.5486 - accuracy: 0.7396 - val_loss: 0.4426 - val_accuracy: 0.8333
# Epoch 4/50
# 48/48 [==============================] - 1s 11ms/step - loss: 0.4108 - accuracy: 0.8313 - val_loss: 0.3290 - val_accuracy: 0.8500
# Epoch 5/50
# 48/48 [==============================] - 0s 10ms/step - loss: 0.2921 - accuracy: 0.8813 - val_loss: 0.2282 - val_accuracy: 0.9167
# Epoch 6/50
# 48/48 [==============================] - 0s 10ms/step - loss: 0.2341 - accuracy: 0.9042 - val_loss: 0.1528 - val_accuracy: 0.9500
# Epoch 7/50
# 48/48 [==============================] - 1s 10ms/step - loss: 0.2247 - accuracy: 0.9083 - val_loss: 0.1300 - val_accuracy: 0.9583
# Epoch 8/50
# 48/48 [==============================] - 1s 11ms/step - loss: 0.1787 - accuracy: 0.9312 - val_loss: 0.1807 - val_accuracy: 0.9167
# Epoch 9/50
# 48/48 [==============================] - 1s 11ms/step - loss: 0.1736 - accuracy: 0.9271 - val_loss: 0.0975 - val_accuracy: 0.9667
# Epoch 10/50
# 48/48 [==============================] - 1s 12ms/step - loss: 0.1399 - accuracy: 0.9458 - val_loss: 0.0865 - val_accuracy: 0.9667
# Epoch 11/50
# 48/48 [==============================] - 1s 13ms/step - loss: 0.1167 - accuracy: 0.9542 - val_loss: 0.2073 - val_accuracy: 0.9000
# Epoch 12/50
# 48/48 [==============================] - 1s 12ms/step - loss: 0.1027 - accuracy: 0.9604 - val_loss: 0.0754 - val_accuracy: 0.9667
# Epoch 13/50
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0871 - accuracy: 0.9708 - val_loss: 0.0886 - val_accuracy: 0.9667
# Epoch 14/50
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0829 - accuracy: 0.9729 - val_loss: 0.1129 - val_accuracy: 0.9500
# Epoch 15/50
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0678 - accuracy: 0.9833 - val_loss: 0.0564 - val_accuracy: 0.9833
# Epoch 16/50
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0869 - accuracy: 0.9688 - val_loss: 0.0716 - val_accuracy: 0.9750
# Epoch 17/50
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0667 - accuracy: 0.9729 - val_loss: 0.0800 - val_accuracy: 0.9750
# Epoch 18/50
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0776 - accuracy: 0.9812 - val_loss: 0.0694 - val_accuracy: 0.9833
# Epoch 19/50
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0613 - accuracy: 0.9854 - val_loss: 0.0900 - val_accuracy: 0.9500
# Epoch 20/50
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0578 - accuracy: 0.9792 - val_loss: 0.1426 - val_accuracy: 0.9417
# Epoch 21/50
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0374 - accuracy: 0.9896 - val_loss: 0.1156 - val_accuracy: 0.9500
# Epoch 22/50
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0661 - accuracy: 0.9854 - val_loss: 0.0581 - val_accuracy: 0.9833
# Epoch 23/50
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0420 - accuracy: 0.9833 - val_loss: 0.0860 - val_accuracy: 0.9667
# Epoch 24/50
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0504 - accuracy: 0.9854 - val_loss: 0.0781 - val_accuracy: 0.9667
# Epoch 25/50
# 48/48 [==============================] - 1s 14ms/step - loss: 0.0411 - accuracy: 0.9875 - val_loss: 0.1538 - val_accuracy: 0.9667
# Epoch 26/50
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0778 - accuracy: 0.9833 - val_loss: 0.0596 - val_accuracy: 0.9833
# Epoch 27/50
# 48/48 [==============================] - 1s 16ms/step - loss: 0.0306 - accuracy: 0.9854 - val_loss: 0.0268 - val_accuracy: 0.9833
# Epoch 28/50
# 48/48 [==============================] - 1s 13ms/step - loss: 0.0518 - accuracy: 0.9854 - val_loss: 0.0522 - val_accuracy: 0.9833
# Epoch 29/50
# 48/48 [==============================] - 1s 10ms/step - loss: 0.0257 - accuracy: 0.9917 - val_loss: 0.1247 - val_accuracy: 0.9583
# Epoch 30/50
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0345 - accuracy: 0.9917 - val_loss: 0.0738 - val_accuracy: 0.9833
# Epoch 31/50
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0304 - accuracy: 0.9875 - val_loss: 0.1530 - val_accuracy: 0.9667
# Epoch 32/50
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0535 - accuracy: 0.9833 - val_loss: 0.0494 - val_accuracy: 0.9833
# Epoch 33/50
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0326 - accuracy: 0.9896 - val_loss: 0.0792 - val_accuracy: 0.9750
# Epoch 34/50
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0289 - accuracy: 0.9896 - val_loss: 0.0431 - val_accuracy: 0.9833
# Epoch 35/50
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0135 - accuracy: 0.9958 - val_loss: 0.0455 - val_accuracy: 0.9833
# Epoch 36/50
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0246 - accuracy: 0.9896 - val_loss: 0.0852 - val_accuracy: 0.9750
# Epoch 37/50
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0332 - accuracy: 0.9896 - val_loss: 0.0262 - val_accuracy: 0.9833
# Epoch 38/50
# 48/48 [==============================] - 1s 14ms/step - loss: 0.0187 - accuracy: 0.9917 - val_loss: 0.0338 - val_accuracy: 0.9833
# Epoch 39/50
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0264 - accuracy: 0.9896 - val_loss: 0.1097 - val_accuracy: 0.9750
# Epoch 40/50
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0098 - accuracy: 0.9979 - val_loss: 0.0228 - val_accuracy: 0.9917
# Epoch 41/50
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0189 - accuracy: 0.9917 - val_loss: 0.0692 - val_accuracy: 0.9750
# Epoch 42/50
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0224 - accuracy: 0.9937 - val_loss: 0.0138 - val_accuracy: 0.9917
# Epoch 43/50
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0565 - accuracy: 0.9875 - val_loss: 0.0381 - val_accuracy: 0.9917
# Epoch 44/50
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0812 - accuracy: 0.9875 - val_loss: 0.0820 - val_accuracy: 0.9750
# Epoch 45/50
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0302 - accuracy: 0.9896 - val_loss: 0.1742 - val_accuracy: 0.9500
# Epoch 46/50
# 48/48 [==============================] - 1s 13ms/step - loss: 0.0143 - accuracy: 0.9917 - val_loss: 0.1133 - val_accuracy: 0.9667
# Epoch 47/50
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0475 - accuracy: 0.9833 - val_loss: 0.0823 - val_accuracy: 0.9750
# Epoch 48/50
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0187 - accuracy: 0.9937 - val_loss: 0.1292 - val_accuracy: 0.9500
# Epoch 49/50
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0166 - accuracy: 0.9958 - val_loss: 0.1227 - val_accuracy: 0.9667
# Epoch 50/50
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0390 - accuracy: 0.9854 - val_loss: 0.0449 - val_accuracy: 0.9833

# %% [markdown]
# # Evaluate / Test

# %%
train_accuracy = history.history['val_accuracy']
train_loss = history.history['val_loss']

count = range(len(train_accuracy))
plt.plot(count, train_accuracy, label='Training accuracy')
plt.plot(count, train_loss, label='Training Loss')
plt.title('epochs vs Training Loss')
plt.legend()

# %% [markdown]
# Evaluate Test set

# %%
score = model.evaluate(X_test, Y_test, verbose=0)
print('Test accuracy:', score[1])
# You should be able to get,at least, 88% accuracy
# Out:
# Test accuracy: 0.9866666793823242

# %%
pred = model.predict(X_test)
predictions = [float(np.round(x)) for x in pred]

# %% [markdown]
# Confusion Matrix

# %%
from sklearn.metrics import f1_score, classification_report,confusion_matrix, ConfusionMatrixDisplay
def conf_matrix(y_test, y_pred, model):
    cm = confusion_matrix(y_test, y_pred, labels=[0, 1])
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
    fig, ax = plt.subplots(figsize=(15,12))
    disp.plot(ax=ax)
    plt.show()
conf_matrix(Y_test, predictions, model)

# %% [markdown]
# # Note
#
# Before you submit your work
#
# * You should compare different optimizers
#
# ---
#
# * Display images with Predicted & expected labels (Happy-sad)

# %%
model.compile(optimizer="adam", loss='binary_crossentropy', metrics=["accuracy"])
model.compile(optimizer="sgd", loss='binary_crossentropy', metrics=["accuracy"])
model.compile(optimizer="Adadelta", loss='binary_crossentropy', metrics=["accuracy"])
model.compile(optimizer="Adagrad", loss='binary_crossentropy', metrics=["accuracy"])
model.compile(optimizer="Adamax", loss='binary_crossentropy', metrics=["accuracy"])
model.compile(optimizer="Nadam", loss='binary_crossentropy', metrics=["accuracy"])
model.compile(optimizer="Ftrl", loss='binary_crossentropy', metrics=["accuracy"])

# %%
text_labels = ["Sad", "Happy"]

# %%
plt.figure(figsize=(10,10))
for i in range(10):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid('off')
    
    img_index = np.random.randint(0, 150)
    plt.imshow(X_test_orig[img_index], cmap=plt.cm.gray)
    actual_label  = Y_test[img_index][0]
    predicted_label = int(predictions[img_index])
    
    plt.xlabel("Actual: {} ({})\n Predicted: {} ({})".format(
        actual_label, text_labels[actual_label], predicted_label, text_labels[predicted_label]
    ))
    
plt.tight_layout()
plt.show()
